# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import model_function

# %%
exponential_count =2
parameter_count = exponential_count*2+1

# %% [markdown]
# Load a model or creat a new one?

# %%
load = True
model_path ='models/2024-01-08_16-14-55_2exp_params_205_points_50/model.keras'

# %%
df = pd.read_csv('measurements/C_4_1000_20231213_14_15_50.csv', sep=', ')
# df = pd.read_csv('measurements/E_4_20ms_20231103_14_55_46.csv', sep=', ')
df.head()
# Out:
# C:\Users\crpdn\AppData\Local\Temp\ipykernel_19564\431649043.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('measurements/C_4_1000_20231213_14_15_50.csv', sep=', ')
#    Ch1(mA)  Ch2(mA)  Ch3(mA)  Ch4(mA)  Ch5(mA)  Ch6(mA)  Ch7(mA)  Ch8(mA)  \
# 0        0        0        0  0.03421        0        0        0        0
# 1        0        0        0  0.04888        0        0        0        0
# 2        0        0        0  0.06354        0        0        0        0
# 3        0        0        0  0.08309        0        0        0        0
# 4        0        0        0  0.09775        0        0        0        0
#
#    Ch9(mA)  Ch10(mA)  ...  Ch14(mA)  Ch15(mA)  Ch16(mA)  Channel state  \
# 0        0         0  ...         0         0         0  1000000000000
# 1        0         0  ...         0         0         0  1000000000000
# 2        0         0  ...         0         0         0  1000000000000
# 3        0         0  ...         0         0         0  1000000000000
# 4        0         0  ...         0         0         0  1000000000000
#
#    On time  Off time  Pulse number  Pattern      Time  Probeflag
# 0       75        22             1   1/1000  0.087664      False
# 1       75        22             2   1/1000  0.182584      False
# 2       75        22             3   1/1000  0.283189      False
# 3       75        22             4   1/1000  0.376060      False
# 4       75        22             5   1/1000  0.469858      False
#
# [5 rows x 23 columns]

# %%
df = df[ ['Pattern','Time','Ch4(mA)','On time', 'Off time']]
df = df.rename(columns={'Ch4(mA)': 'Current'})
df = df.drop(df.index[:50*10])
df = df.iloc[1000:1050]
df.head()
# Out:
#       Pattern        Time  Current  On time  Off time
# 1500  31/1000  225.214643   0.4448       47        68
# 1501  31/1000  225.328495   0.4839       47        68
# 1502  31/1000  225.445176   0.5034       47        68
# 1503  31/1000  225.561147   0.5279       47        68
# 1504  31/1000  225.674205   0.5474       47        68

# %%
target_points = 50
cutoff_current_min = 0
must_be_growth = False
must_be_decay = False
min_gradient =0
max_final_gradient = 1

# %%
grouped = df.groupby('Pattern')
list_of_dfs = [group for _, group in grouped]
list_of_dfs_fixed = []
for data in list_of_dfs:    
    x_time = data['Time']-np.min(data['Time'])
    y_current = data['Current']
    points = len(y_current)    
    #(data.loc[0,'Off time'])
    if len(y_current) != target_points:
        print(points)
        continue
    assert x_time.shape == y_current.shape
    assert points == target_points
    if np.min(y_current)>cutoff_current_min and np.max(np.abs(np.gradient(y_current,y_current.index)))>min_gradient and np.min(np.abs(np.gradient(y_current,y_current.index)[:-10]))<max_final_gradient:
        if must_be_growth:
            if y_current.iloc[0]<y_current.iloc[-1]:
                plt.plot(x_time, y_current, '-')
                list_of_dfs_fixed.append(data)
        elif   must_be_decay:
            if y_current.iloc[0]>y_current.iloc[-1]:
                plt.plot(x_time, y_current, '-')
                list_of_dfs_fixed.append(data)          
        else:
            plt.plot(x_time, y_current, '-')
            list_of_dfs_fixed.append(data)
plt.xlabel('Time')
plt.ylabel('Current')
plt.title('Data to be modeled')
# Out:
# Text(0.5, 1.0, 'Data to be modeled')

# %%
#initialize array of expected shape
X_data = np.zeros((len(list_of_dfs_fixed),3))
#initialize array of expected shape
y_data = np.zeros((len(list_of_dfs_fixed), points, 2))

for i in range(len(list_of_dfs_fixed)):
    data = list_of_dfs_fixed[i]
    x_time = data['Time']-np.min(data['Time'])
    y_current = data['Current']
    
    if len(y_current) != target_points:
        print(points)
        continue
    if np.max(y_current)>cutoff_current_min:
        label = np.column_stack((x_time,y_current))  
        y_data[i,:,:]= label
        features =  np.array([np.min(y_current.values), data['On time'].iloc[0], data['Off time'].iloc[0]])
        X_data[i,:] = features
    prev_on_time = data['On time'].iloc[0]
    prev_off_time = data['Off time'].iloc[0]

print(f"X shape:{X_data.shape}")
print(f"y shape:{y_data.shape}")
# Out:
# X shape:(1, 3)
# y shape:(1, 50, 2)

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.0, train_size=1.0)
X_train = X_data
y_train = y_data

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)
# X_test = scaler.transform(X_test)

# %%
import keras

import tensorflow.keras.backend as K

def custom_loss(y_true, y_pred):
    """
    Custom loss function for the specified task.

    Parameters:
    - y_true: Ground truth values, of shape (batch_size, 2, N).
    - y_pred: Predicted values, of shape (batch_size, 7,N).

    Returns:
    - loss: Scalar value representing the mean loss over the batch.
    """

    # Extract x and y values from y_true
    x_values = y_true[:,:,0]  # Shape: (batch_size, N)
    y_values = y_true[:,:,1]  # Shape: (batch_size, N)
    
    function_values = tf.zeros_like(x_values)
    for i in range(int((y_pred.shape[2]-1)/2)):
        temp_val= y_pred[:, :,i]*i * K.exp(-(x_values) * y_pred[:, :,i+1]*i)
        function_values = function_values+ temp_val
    function_values = function_values+y_pred[:,:,-1]
    
    # square absolute error
    diff = (y_values -function_values) 
    squared_diff = tf.math.square(diff)
    mse = tf.math.reduce_sum(squared_diff, axis=-1)


    # diff = function_values - y_values
    # # print(diff)
    # # Take the square of the differences
    # squared_diff = K.square(diff)

    # slope_comparison = 0.0
    # for i in range(y_true.shape[2]-1):
    #     x_diff = x_values[:,i+1]-x_values[:,i]  
    #     function_slope = (function_values[:,i+1]-function_values[:,i])/x_diff 
    #     true_slope= (y_values[:,i+1]-y_values[:,i])/x_diff
    #     slope_comparison += tf.math.square(true_slope- function_slope)      

    # square relative error
    # diff = (y_values -function_values) / (y_values+0.0001) #K.maximum(y_values, y_values+0.00001)
    # squared_diff = tf.math.square(diff)
    # mse = tf.math.reduce_sum(squared_diff, axis=-1)

    loss = mse #+ slope_comparison
    # loss = K.mean(squared_diff, axis=-1)
    return loss
 

def create_nn():
    global X_train, points
    # Input layer, the number of input nodes is governed by X_data.shape[1]
    # X_data.shape[1] is the number of columns in X_data
    inputs = keras.Input(shape=(X_train.shape[1],), name='input')
    
    # Dense layers 
    #layers_norm = keras.layers.BatchNormalization()(inputs)
    layers_dense = keras.layers.Dense(10, 'linear')(inputs)
    layers_dense2 = keras.layers.Dense(10, 'linear')(layers_dense)
    # layers_dense3 = keras.layers.Dense(20, 'linear')(layers_dense2)
    # layers_dense4 = keras.layers.Dense(20, 'linear')(layers_dense3)
    # Parameter layer
    # layers_norm = keras.layers.LayerNormalization()(layers_dense2)
    parameters = keras.layers.Dense(parameter_count)(layers_dense2)
    # Expand parameters to have same shape as y_true
    expanded_parameters = keras.layers.RepeatVector(points)(parameters)


    return keras.Model(inputs=inputs, outputs=expanded_parameters, name="current_function_prediction")

# %%
if load:
    model = keras.models.load_model(model_path, custom_objects={'custom_loss':custom_loss})
else:
    model = create_nn()

model.summary()
# Out:
# Model: "current_function_prediction"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 3)]               0
#
#  dense_12 (Dense)            (None, 10)                40
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 5)                 55
#
#  repeat_vector_4 (RepeatVec  (None, 50, 5)             0
#  tor)
#
# =================================================================
# Total params: 205 (820.00 Byte)
# Trainable params: 205 (820.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def compile_model(model):
    sgd = keras.optimizers.RMSprop(clipnorm=5)
    model.compile(optimizer=sgd, #'adam'
                  loss=custom_loss)
    


number_of_epochs = 1000


class MyEarlyStopping(EarlyStopping):
    def __init__(self, *args, **kw):
        super().__init__(*args, **kw)
        self.baseline_attained = False

    def on_epoch_end(self, epoch, logs=None):
        if not self.baseline_attained:
            current = self.get_monitor_value(logs)
            if current is None:
                return

            if self.monitor_op(current, self.baseline):
                if self.verbose > 0:
                    print('Baseline attained.')
                self.baseline_attained = True
            else:
                return

        super(MyEarlyStopping, self).on_epoch_end(epoch, logs)

earlystopper = keras.callbacks.EarlyStopping(monitor="loss", patience=20, baseline = 0.1, restore_best_weights=True)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='loss', 
                              factor=0.8, 
                              patience=5, 
                              min_lr=1e-6)
compile_model(model)

import seaborn as sns
def plot_history(history, metrics, y_lim):
    """
    Plot the training history

    Args:
        history (keras History object that is returned by model.fit())
        metrics (str, list): Metric or a list of metrics to plot
    """
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    if y_lim !=0:
        plt.ylim(0,y_lim)
    plt.xlabel("epochs")
    plt.ylabel("metric")

# %%
history = model.fit(X_train, y_train,
                    batch_size=1,
                    epochs=number_of_epochs,
                    # validation_data = (X_val,y_val),
                    callbacks=[earlystopper
                               ,reduce_lr
                               ],
                    verbose=2)
# Out:
# Epoch 1/1000
# 1/1 - 0s - loss: 3535.0703 - lr: 0.0010 - 483ms/epoch - 483ms/step
# Epoch 2/1000
# 1/1 - 0s - loss: 1507.5890 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 517.3630 - lr: 0.0010 - 4ms/epoch - 4ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 124.0875 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 51.4809 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 55.9213 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 23.0240 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 36.8627 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 14.5392 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 29.2158 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 11.3862 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 25.5898 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 9.9778 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 23.5194 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 9.2049 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 22.1424 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 8.7189 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 18/1000
# 1/1 - 0s - loss: 21.1363 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 19/1000
# 1/1 - 0s - loss: 8.3978 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 20/1000
# 1/1 - 0s - loss: 20.3607 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 21/1000
# 1/1 - 0s - loss: 8.1852 - lr: 0.0010 - 4ms/epoch - 4ms/step
# Epoch 22/1000
# 1/1 - 0s - loss: 19.7423 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 23/1000
# 1/1 - 0s - loss: 8.0502 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 24/1000
# 1/1 - 0s - loss: 19.2338 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 25/1000
# 1/1 - 0s - loss: 7.9709 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 26/1000
# 1/1 - 0s - loss: 18.8061 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 27/1000
# 1/1 - 0s - loss: 7.9339 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 28/1000
# 1/1 - 0s - loss: 18.4385 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 29/1000
# 1/1 - 0s - loss: 7.9287 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 30/1000
# 1/1 - 0s - loss: 18.1153 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 31/1000
# 1/1 - 0s - loss: 7.9477 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 32/1000
# 1/1 - 0s - loss: 17.8261 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 33/1000
# 1/1 - 0s - loss: 7.9861 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 34/1000
# 1/1 - 0s - loss: 17.5631 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 35/1000
# 1/1 - 0s - loss: 8.0398 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 36/1000
# 1/1 - 0s - loss: 7.7886 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 37/1000
# 1/1 - 0s - loss: 8.0793 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 38/1000
# 1/1 - 0s - loss: 7.6855 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 39/1000
# 1/1 - 0s - loss: 8.1260 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 40/1000
# 1/1 - 0s - loss: 7.5880 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 41/1000
# 1/1 - 0s - loss: 8.1788 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 42/1000
# 1/1 - 0s - loss: 7.4951 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 43/1000
# 1/1 - 0s - loss: 8.2366 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 44/1000
# 1/1 - 0s - loss: 7.4064 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 45/1000
# 1/1 - 0s - loss: 8.2983 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 46/1000
# 1/1 - 0s - loss: 7.3205 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 47/1000
# 1/1 - 0s - loss: 8.3637 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 48/1000
# 1/1 - 0s - loss: 7.2369 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 49/1000
# 1/1 - 0s - loss: 8.4323 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 50/1000
# 1/1 - 0s - loss: 7.1552 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 51/1000
# 1/1 - 0s - loss: 8.5033 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 52/1000
# 1/1 - 0s - loss: 7.0748 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 53/1000
# 1/1 - 0s - loss: 8.5764 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 54/1000
# 1/1 - 0s - loss: 6.9954 - lr: 8.0000e-04 - 6ms/epoch - 6ms/step
# Epoch 55/1000
# 1/1 - 0s - loss: 8.6521 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 56/1000
# 1/1 - 0s - loss: 6.9169 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 57/1000
# 1/1 - 0s - loss: 8.7297 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 58/1000
# 1/1 - 0s - loss: 6.8390 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 59/1000
# 1/1 - 0s - loss: 8.8087 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 60/1000
# 1/1 - 0s - loss: 6.7618 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 61/1000
# 1/1 - 0s - loss: 8.8898 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 62/1000
# 1/1 - 0s - loss: 6.6847 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 63/1000
# 1/1 - 0s - loss: 8.9726 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 64/1000
# 1/1 - 0s - loss: 6.6076 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 65/1000
# 1/1 - 0s - loss: 9.0571 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 66/1000
# 1/1 - 0s - loss: 6.5305 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 67/1000
# 1/1 - 0s - loss: 9.1432 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 68/1000
# 1/1 - 0s - loss: 6.4535 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 69/1000
# 1/1 - 0s - loss: 9.2311 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 70/1000
# 1/1 - 0s - loss: 6.3766 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 71/1000
# 1/1 - 0s - loss: 9.3204 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 72/1000
# 1/1 - 0s - loss: 6.2995 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 73/1000
# 1/1 - 0s - loss: 9.4108 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 74/1000
# 1/1 - 0s - loss: 6.2223 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 75/1000
# 1/1 - 0s - loss: 9.5025 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 76/1000
# 1/1 - 0s - loss: 6.1454 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 77/1000
# 1/1 - 0s - loss: 9.5946 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 78/1000
# 1/1 - 0s - loss: 6.0685 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 79/1000
# 1/1 - 0s - loss: 9.6875 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 80/1000
# 1/1 - 0s - loss: 5.9921 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 81/1000
# 1/1 - 0s - loss: 9.7811 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 82/1000
# 1/1 - 0s - loss: 5.9163 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 83/1000
# 1/1 - 0s - loss: 9.8750 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 84/1000
# 1/1 - 0s - loss: 5.8406 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 85/1000
# 1/1 - 0s - loss: 9.9700 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 86/1000
# 1/1 - 0s - loss: 5.7653 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 87/1000
# 1/1 - 0s - loss: 10.0653 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 88/1000
# 1/1 - 0s - loss: 5.6905 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 89/1000
# 1/1 - 0s - loss: 10.1611 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 90/1000
# 1/1 - 0s - loss: 5.6160 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 91/1000
# 1/1 - 0s - loss: 10.2574 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 92/1000
# 1/1 - 0s - loss: 5.5418 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 93/1000
# 1/1 - 0s - loss: 10.3545 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 94/1000
# 1/1 - 0s - loss: 5.4686 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 95/1000
# 1/1 - 0s - loss: 10.4518 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 96/1000
# 1/1 - 0s - loss: 5.3954 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 97/1000
# 1/1 - 0s - loss: 10.5494 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 98/1000
# 1/1 - 0s - loss: 5.3228 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 99/1000
# 1/1 - 0s - loss: 10.6474 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 100/1000
# 1/1 - 0s - loss: 5.2508 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 101/1000
# 1/1 - 0s - loss: 10.7466 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 102/1000
# 1/1 - 0s - loss: 5.1791 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 103/1000
# 1/1 - 0s - loss: 10.8456 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 104/1000
# 1/1 - 0s - loss: 5.1079 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 105/1000
# 1/1 - 0s - loss: 10.9455 - lr: 8.0000e-04 - 6ms/epoch - 6ms/step
# Epoch 106/1000
# 1/1 - 0s - loss: 5.0372 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 107/1000
# 1/1 - 0s - loss: 11.0455 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 108/1000
# 1/1 - 0s - loss: 4.9670 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 109/1000
# 1/1 - 0s - loss: 11.1463 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 110/1000
# 1/1 - 0s - loss: 4.8975 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 111/1000
# 1/1 - 0s - loss: 11.2475 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 112/1000
# 1/1 - 0s - loss: 4.8284 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 113/1000
# 1/1 - 0s - loss: 11.3489 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 114/1000
# 1/1 - 0s - loss: 4.7596 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 115/1000
# 1/1 - 0s - loss: 11.4509 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 116/1000
# 1/1 - 0s - loss: 4.6915 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 117/1000
# 1/1 - 0s - loss: 11.5536 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 118/1000
# 1/1 - 0s - loss: 4.6238 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 119/1000
# 1/1 - 0s - loss: 11.6566 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 120/1000
# 1/1 - 0s - loss: 4.5568 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 121/1000
# 1/1 - 0s - loss: 11.7601 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 122/1000
# 1/1 - 0s - loss: 4.4901 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 123/1000
# 1/1 - 0s - loss: 11.8641 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 124/1000
# 1/1 - 0s - loss: 4.4242 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 125/1000
# 1/1 - 0s - loss: 11.9684 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 126/1000
# 1/1 - 0s - loss: 4.3586 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 127/1000
# 1/1 - 0s - loss: 12.0732 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 128/1000
# 1/1 - 0s - loss: 4.2936 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 129/1000
# 1/1 - 0s - loss: 12.1782 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 130/1000
# 1/1 - 0s - loss: 4.2290 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 131/1000
# 1/1 - 0s - loss: 12.2842 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 132/1000
# 1/1 - 0s - loss: 4.1651 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 133/1000
# 1/1 - 0s - loss: 12.3904 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 134/1000
# 1/1 - 0s - loss: 4.1016 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 135/1000
# 1/1 - 0s - loss: 12.4971 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 136/1000
# 1/1 - 0s - loss: 4.0387 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 137/1000
# 1/1 - 0s - loss: 12.6043 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 138/1000
# 1/1 - 0s - loss: 3.9761 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 139/1000
# 1/1 - 0s - loss: 12.7125 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 140/1000
# 1/1 - 0s - loss: 3.9141 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 141/1000
# 1/1 - 0s - loss: 12.8203 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 142/1000
# 1/1 - 0s - loss: 3.8528 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 143/1000
# 1/1 - 0s - loss: 12.9288 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 144/1000
# 1/1 - 0s - loss: 3.7919 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 145/1000
# 1/1 - 0s - loss: 13.0379 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 146/1000
# 1/1 - 0s - loss: 3.7316 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 147/1000
# 1/1 - 0s - loss: 13.1475 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 148/1000
# 1/1 - 0s - loss: 3.6716 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 149/1000
# 1/1 - 0s - loss: 13.2575 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 150/1000
# 1/1 - 0s - loss: 3.6123 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 151/1000
# 1/1 - 0s - loss: 13.3680 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 152/1000
# 1/1 - 0s - loss: 3.5536 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 153/1000
# 1/1 - 0s - loss: 13.4788 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 154/1000
# 1/1 - 0s - loss: 3.4954 - lr: 8.0000e-04 - 7ms/epoch - 7ms/step
# Epoch 155/1000
# 1/1 - 0s - loss: 13.5901 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 156/1000
# 1/1 - 0s - loss: 3.4376 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 157/1000
# 1/1 - 0s - loss: 13.7017 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 158/1000
# 1/1 - 0s - loss: 3.3805 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 159/1000
# 1/1 - 0s - loss: 13.8138 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 160/1000
# 1/1 - 0s - loss: 3.3238 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 161/1000
# 1/1 - 0s - loss: 13.9270 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 162/1000
# 1/1 - 0s - loss: 3.2675 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 163/1000
# 1/1 - 0s - loss: 14.0397 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 164/1000
# 1/1 - 0s - loss: 3.2119 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 165/1000
# 1/1 - 0s - loss: 14.1533 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 166/1000
# 1/1 - 0s - loss: 3.1567 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 167/1000
# 1/1 - 0s - loss: 14.2673 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 168/1000
# 1/1 - 0s - loss: 3.1023 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 169/1000
# 1/1 - 0s - loss: 14.3820 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 170/1000
# 1/1 - 0s - loss: 3.0482 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 171/1000
# 1/1 - 0s - loss: 14.4965 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 172/1000
# 1/1 - 0s - loss: 2.9946 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 173/1000
# 1/1 - 0s - loss: 14.6120 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 174/1000
# 1/1 - 0s - loss: 2.9417 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 175/1000
# 1/1 - 0s - loss: 14.7277 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 176/1000
# 1/1 - 0s - loss: 2.8892 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 177/1000
# 1/1 - 0s - loss: 14.8440 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 178/1000
# 1/1 - 0s - loss: 2.8372 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 179/1000
# 1/1 - 0s - loss: 14.9606 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 180/1000
# 1/1 - 0s - loss: 2.7858 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 181/1000
# 1/1 - 0s - loss: 15.0777 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 182/1000
# 1/1 - 0s - loss: 2.7349 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 183/1000
# 1/1 - 0s - loss: 15.1954 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 184/1000
# 1/1 - 0s - loss: 2.6844 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 185/1000
# 1/1 - 0s - loss: 15.3133 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 186/1000
# 1/1 - 0s - loss: 2.6346 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 187/1000
# 1/1 - 0s - loss: 15.4318 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 188/1000
# 1/1 - 0s - loss: 2.5852 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 189/1000
# 1/1 - 0s - loss: 15.5505 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 190/1000
# 1/1 - 0s - loss: 2.5365 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 191/1000
# 1/1 - 0s - loss: 15.6693 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 192/1000
# 1/1 - 0s - loss: 2.4882 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 193/1000
# 1/1 - 0s - loss: 15.7889 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 194/1000
# 1/1 - 0s - loss: 2.4406 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 195/1000
# 1/1 - 0s - loss: 15.9091 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 196/1000
# 1/1 - 0s - loss: 2.3934 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 197/1000
# 1/1 - 0s - loss: 16.0290 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 198/1000
# 1/1 - 0s - loss: 2.3468 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 199/1000
# 1/1 - 0s - loss: 16.1493 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 200/1000
# 1/1 - 0s - loss: 2.3009 - lr: 8.0000e-04 - 6ms/epoch - 6ms/step
# Epoch 201/1000
# 1/1 - 0s - loss: 16.2706 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 202/1000
# 1/1 - 0s - loss: 2.2554 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 203/1000
# 1/1 - 0s - loss: 16.3919 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 204/1000
# 1/1 - 0s - loss: 2.2103 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 205/1000
# 1/1 - 0s - loss: 16.5131 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 206/1000
# 1/1 - 0s - loss: 2.1660 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 207/1000
# 1/1 - 0s - loss: 16.6351 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 208/1000
# 1/1 - 0s - loss: 2.1221 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 209/1000
# 1/1 - 0s - loss: 16.7575 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 210/1000
# 1/1 - 0s - loss: 2.0787 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 211/1000
# 1/1 - 0s - loss: 16.8802 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 212/1000
# 1/1 - 0s - loss: 2.0360 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 213/1000
# 1/1 - 0s - loss: 17.0025 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 214/1000
# 1/1 - 0s - loss: 1.9939 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 215/1000
# 1/1 - 0s - loss: 17.1253 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 216/1000
# 1/1 - 0s - loss: 1.9525 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 217/1000
# 1/1 - 0s - loss: 17.2471 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 218/1000
# 1/1 - 0s - loss: 1.9120 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 219/1000
# 1/1 - 0s - loss: 17.3682 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 220/1000
# 1/1 - 0s - loss: 1.8747 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 221/1000
# 1/1 - 0s - loss: 17.5053 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 222/1000
# 1/1 - 0s - loss: 1.8393 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 223/1000
# 1/1 - 0s - loss: 17.5753 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 224/1000
# 1/1 - 0s - loss: 1.8127 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 225/1000
# 1/1 - 0s - loss: 17.7899 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 226/1000
# 1/1 - 0s - loss: 1.7579 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 227/1000
# 1/1 - 0s - loss: 17.8530 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 228/1000
# 1/1 - 0s - loss: 1.7191 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 229/1000
# 1/1 - 0s - loss: 17.9814 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 230/1000
# 1/1 - 0s - loss: 1.6802 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 231/1000
# 1/1 - 0s - loss: 18.1074 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 232/1000
# 1/1 - 0s - loss: 1.6426 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 233/1000
# 1/1 - 0s - loss: 18.2343 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 234/1000
# 1/1 - 0s - loss: 1.6057 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 235/1000
# 1/1 - 0s - loss: 18.3618 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 236/1000
# 1/1 - 0s - loss: 1.5693 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 237/1000
# 1/1 - 0s - loss: 18.4892 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 238/1000
# 1/1 - 0s - loss: 1.5334 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 239/1000
# 1/1 - 0s - loss: 18.6171 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 240/1000
# 1/1 - 0s - loss: 1.4979 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 241/1000
# 1/1 - 0s - loss: 18.7451 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 242/1000
# 1/1 - 0s - loss: 1.4632 - lr: 8.0000e-04 - 7ms/epoch - 7ms/step
# Epoch 243/1000
# 1/1 - 0s - loss: 18.8729 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 244/1000
# 1/1 - 0s - loss: 1.4291 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 245/1000
# 1/1 - 0s - loss: 18.9998 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 246/1000
# 1/1 - 0s - loss: 1.3959 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 247/1000
# 1/1 - 0s - loss: 19.1260 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 248/1000
# 1/1 - 0s - loss: 1.3635 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 249/1000
# 1/1 - 0s - loss: 19.2508 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 250/1000
# 1/1 - 0s - loss: 1.3318 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 251/1000
# 1/1 - 0s - loss: 19.3907 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 252/1000
# 1/1 - 0s - loss: 1.3023 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 253/1000
# 1/1 - 0s - loss: 19.5561 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 254/1000
# 1/1 - 0s - loss: 1.2653 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 255/1000
# 1/1 - 0s - loss: 19.7354 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 256/1000
# 1/1 - 0s - loss: 1.2338 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 257/1000
# 1/1 - 0s - loss: 19.7744 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 258/1000
# 1/1 - 0s - loss: 1.2032 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 259/1000
# 1/1 - 0s - loss: 19.9067 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 260/1000
# 1/1 - 0s - loss: 1.1744 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 261/1000
# 1/1 - 0s - loss: 20.0311 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 262/1000
# 1/1 - 0s - loss: 1.1453 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 263/1000
# 1/1 - 0s - loss: 20.1613 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 264/1000
# 1/1 - 0s - loss: 1.1163 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 265/1000
# 1/1 - 0s - loss: 20.2920 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 266/1000
# 1/1 - 0s - loss: 1.0885 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 267/1000
# 1/1 - 0s - loss: 20.4220 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 268/1000
# 1/1 - 0s - loss: 1.0613 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 269/1000
# 1/1 - 0s - loss: 20.5495 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 270/1000
# 1/1 - 0s - loss: 1.0345 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 271/1000
# 1/1 - 0s - loss: 20.6774 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 272/1000
# 1/1 - 0s - loss: 1.0077 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 273/1000
# 1/1 - 0s - loss: 20.8091 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 274/1000
# 1/1 - 0s - loss: 0.9805 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 275/1000
# 1/1 - 0s - loss: 20.9440 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 276/1000
# 1/1 - 0s - loss: 0.9561 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 277/1000
# 1/1 - 0s - loss: 21.1260 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 278/1000
# 1/1 - 0s - loss: 0.9329 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 279/1000
# 1/1 - 0s - loss: 21.2070 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 280/1000
# 1/1 - 0s - loss: 0.9074 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 281/1000
# 1/1 - 0s - loss: 21.3653 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 282/1000
# 1/1 - 0s - loss: 0.8783 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 283/1000
# 1/1 - 0s - loss: 21.5444 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 284/1000
# 1/1 - 0s - loss: 0.8558 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 285/1000
# 1/1 - 0s - loss: 21.6077 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 286/1000
# 1/1 - 0s - loss: 0.8308 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 287/1000
# 1/1 - 0s - loss: 21.7715 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 288/1000
# 1/1 - 0s - loss: 0.8093 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 289/1000
# 1/1 - 0s - loss: 21.8711 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 290/1000
# 1/1 - 0s - loss: 0.7856 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 291/1000
# 1/1 - 0s - loss: 22.0388 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 292/1000
# 1/1 - 0s - loss: 0.7649 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 293/1000
# 1/1 - 0s - loss: 22.1362 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 294/1000
# 1/1 - 0s - loss: 0.7426 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 295/1000
# 1/1 - 0s - loss: 22.3084 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 296/1000
# 1/1 - 0s - loss: 0.7228 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 297/1000
# 1/1 - 0s - loss: 22.4015 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 298/1000
# 1/1 - 0s - loss: 0.7016 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 299/1000
# 1/1 - 0s - loss: 22.5868 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 300/1000
# 1/1 - 0s - loss: 0.6834 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 301/1000
# 1/1 - 0s - loss: 22.6676 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 302/1000
# 1/1 - 0s - loss: 0.6637 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 303/1000
# 1/1 - 0s - loss: 22.8818 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 304/1000
# 1/1 - 0s - loss: 0.6523 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 305/1000
# 1/1 - 0s - loss: 22.9329 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 306/1000
# 1/1 - 0s - loss: 0.6472 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 307/1000
# 1/1 - 0s - loss: 23.0616 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 308/1000
# 1/1 - 0s - loss: 0.6792 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 309/1000
# 1/1 - 0s - loss: 22.9110 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 310/1000
# 1/1 - 0s - loss: 0.7088 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 311/1000
# 1/1 - 0s - loss: 22.6151 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 312/1000
# 1/1 - 0s - loss: 0.7893 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 313/1000
# 1/1 - 0s - loss: 13.3562 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 314/1000
# 1/1 - 0s - loss: 0.7243 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 315/1000
# 1/1 - 0s - loss: 13.3099 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 316/1000
# 1/1 - 0s - loss: 0.7116 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 317/1000
# 1/1 - 0s - loss: 13.3573 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 318/1000
# 1/1 - 0s - loss: 0.2756 - lr: 5.1200e-04 - 4ms/epoch - 4ms/step
# Epoch 319/1000
# 1/1 - 0s - loss: 10.6738 - lr: 5.1200e-04 - 3ms/epoch - 3ms/step
# Epoch 320/1000
# 1/1 - 0s - loss: 0.3299 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 321/1000
# 1/1 - 0s - loss: 10.0887 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 322/1000
# 1/1 - 0s - loss: 0.4930 - lr: 5.1200e-04 - 3ms/epoch - 3ms/step
# Epoch 323/1000
# 1/1 - 0s - loss: 8.8780 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 324/1000
# 1/1 - 0s - loss: 0.5909 - lr: 4.0960e-04 - 3ms/epoch - 3ms/step
# Epoch 325/1000
# 1/1 - 0s - loss: 5.0305 - lr: 4.0960e-04 - 2ms/epoch - 2ms/step
# Epoch 326/1000
# 1/1 - 0s - loss: 0.5205 - lr: 4.0960e-04 - 2ms/epoch - 2ms/step
# Epoch 327/1000
# 1/1 - 0s - loss: 5.0123 - lr: 4.0960e-04 - 5ms/epoch - 5ms/step
# Epoch 328/1000
# 1/1 - 0s - loss: 0.5248 - lr: 4.0960e-04 - 5ms/epoch - 5ms/step
# Epoch 329/1000
# 1/1 - 0s - loss: 4.9982 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 330/1000
# 1/1 - 0s - loss: 0.2114 - lr: 3.2768e-04 - 5ms/epoch - 5ms/step
# Epoch 331/1000
# 1/1 - 0s - loss: 4.1506 - lr: 3.2768e-04 - 5ms/epoch - 5ms/step
# Epoch 332/1000
# 1/1 - 0s - loss: 0.2443 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 333/1000
# 1/1 - 0s - loss: 4.0985 - lr: 3.2768e-04 - 2ms/epoch - 2ms/step
# Epoch 334/1000
# 1/1 - 0s - loss: 0.2516 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 335/1000
# 1/1 - 0s - loss: 3.9441 - lr: 3.2768e-04 - 2ms/epoch - 2ms/step
# Epoch 336/1000
# 1/1 - 0s - loss: 0.2724 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 337/1000
# 1/1 - 0s - loss: 2.3861 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 338/1000
# 1/1 - 0s - loss: 0.2687 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 339/1000
# 1/1 - 0s - loss: 2.3369 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 340/1000
# 1/1 - 0s - loss: 0.2745 - lr: 2.6214e-04 - 3ms/epoch - 3ms/step
# Epoch 341/1000
# 1/1 - 0s - loss: 2.3176 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 342/1000
# 1/1 - 0s - loss: 0.1827 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 343/1000
# 1/1 - 0s - loss: 2.0706 - lr: 2.0972e-04 - 3ms/epoch - 3ms/step
# Epoch 344/1000
# 1/1 - 0s - loss: 0.1829 - lr: 2.0972e-04 - 3ms/epoch - 3ms/step
# Epoch 345/1000
# 1/1 - 0s - loss: 1.6136 - lr: 2.0972e-04 - 3ms/epoch - 3ms/step
# Epoch 346/1000
# 1/1 - 0s - loss: 0.3378 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 347/1000
# 1/1 - 0s - loss: 1.3612 - lr: 2.0972e-04 - 3ms/epoch - 3ms/step
# Epoch 348/1000
# 1/1 - 0s - loss: 0.2592 - lr: 1.6777e-04 - 2ms/epoch - 2ms/step
# Epoch 349/1000
# 1/1 - 0s - loss: 0.8241 - lr: 1.6777e-04 - 2ms/epoch - 2ms/step
# Epoch 350/1000
# 1/1 - 0s - loss: 0.2575 - lr: 1.6777e-04 - 3ms/epoch - 3ms/step

# %%
# call the plot_history function with the apropriate object and string
plot_history(history, ['loss'], 0)

# %%
# # Save the model
# import os
# from datetime import datetime
# current_date = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
# # filename = f"{current_date}_RMSE_params_{model.count_params()}_points_{points}.keras"
# # model.save('models/'+filename)


# folder_path = f'models/{current_date}_{exponential_count}exp_params_{model.count_params()}_points_{points}'
# os.makedirs(folder_path, exist_ok=True)
# model.save(folder_path+'/model.keras')

# %%
# make prediction on test data
y_train_prediction = model.predict(X_train)
# Out:
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000155D2343EC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 51ms/step

# %%
plt.figure(figsize=(12, 6))

y_train_prediction = model.predict(X_train)

# from matplotlib.pyplot import cm
# color = iter(cm.rainbow(np.linspace(0, 1, X_test.shape[0]-5)))
plt.subplot(1, 2, 1)
for test_entry_index in range(X_train.shape[0]):
    y_true = y_train[test_entry_index,:,:]
    param_predicted = y_train_prediction[test_entry_index,0 ,: ]
    plt.plot(y_true[:,0], -(y_true[:,1]- model_function.exponential_function_param_specific(y_true[:,0], param_predicted))/y_true[:,1], '-', color = 'C0', alpha = 0.3, )


plt.xlabel('time')
plt.ylabel('Relative error')
plt.title('Relative Error of test data prediction')
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Text(0.5, 1.0, 'Relative Error of test data prediction')

# %% [markdown]
# Relative error plots

# %%
plt.figure(figsize=(12, 6))

y_train_prediction = model.predict(X_train)

plt.subplot(1, 2, 1)
for test_entry_index in range(X_train.shape[0]):
    y_true = y_train[test_entry_index,:,:]
    param_predicted = y_train_prediction[test_entry_index,0 ,: ]
    plt.plot(y_true[:,0], y_true[:,1], '-', color = 'C0', alpha = 0.3, )
    plt.plot(y_true[:,0], model_function.exponential_function_param_specific(y_true[:,0], param_predicted), '-', color = 'C0', alpha = 1, )

    
plt.xlabel('time')
plt.ylabel('Current (mA)')
plt.title('True vs prediction')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Text(0.5, 1.0, 'True vs prediction')
