# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import model_function

# %%
exponential_count =2
parameter_count = exponential_count*2+1

# %% [markdown]
# Load a model or creat a new one?

# %%
load = True
model_path ='models/2024-01-08_16-14-55_2exp_params_205_points_50/model.keras'

# %%
df = pd.read_csv('measurements/C_4_1000_20231213_14_15_50.csv', sep=', ')
# df = pd.read_csv('measurements/E_4_20ms_20231103_14_55_46.csv', sep=', ')
df.head()
# Out:
# C:\Users\crpdn\AppData\Local\Temp\ipykernel_5604\431649043.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('measurements/C_4_1000_20231213_14_15_50.csv', sep=', ')
#    Ch1(mA)  Ch2(mA)  Ch3(mA)  Ch4(mA)  Ch5(mA)  Ch6(mA)  Ch7(mA)  Ch8(mA)  \
# 0        0        0        0  0.03421        0        0        0        0
# 1        0        0        0  0.04888        0        0        0        0
# 2        0        0        0  0.06354        0        0        0        0
# 3        0        0        0  0.08309        0        0        0        0
# 4        0        0        0  0.09775        0        0        0        0
#
#    Ch9(mA)  Ch10(mA)  ...  Ch14(mA)  Ch15(mA)  Ch16(mA)  Channel state  \
# 0        0         0  ...         0         0         0  1000000000000
# 1        0         0  ...         0         0         0  1000000000000
# 2        0         0  ...         0         0         0  1000000000000
# 3        0         0  ...         0         0         0  1000000000000
# 4        0         0  ...         0         0         0  1000000000000
#
#    On time  Off time  Pulse number  Pattern      Time  Probeflag
# 0       75        22             1   1/1000  0.087664      False
# 1       75        22             2   1/1000  0.182584      False
# 2       75        22             3   1/1000  0.283189      False
# 3       75        22             4   1/1000  0.376060      False
# 4       75        22             5   1/1000  0.469858      False
#
# [5 rows x 23 columns]

# %%
df = df[ ['Pattern','Time','Ch4(mA)','On time', 'Off time']]
df = df.rename(columns={'Ch4(mA)': 'Current'})
df = df.drop(df.index[:50*10])
df = df.iloc[1000:1050]
df.head()
# Out:
#       Pattern        Time  Current  On time  Off time
# 1500  31/1000  225.214643   0.4448       47        68
# 1501  31/1000  225.328495   0.4839       47        68
# 1502  31/1000  225.445176   0.5034       47        68
# 1503  31/1000  225.561147   0.5279       47        68
# 1504  31/1000  225.674205   0.5474       47        68

# %%
target_points = 50
cutoff_current_min = 0
must_be_growth = False
must_be_decay = False
min_gradient =0
max_final_gradient = 1

# %%
grouped = df.groupby('Pattern')
list_of_dfs = [group for _, group in grouped]
list_of_dfs_fixed = []
for data in list_of_dfs:    
    x_time = data['Time']-np.min(data['Time'])
    y_current = data['Current']
    points = len(y_current)    
    #(data.loc[0,'Off time'])
    if len(y_current) != target_points:
        print(points)
        continue
    assert x_time.shape == y_current.shape
    assert points == target_points
    if np.min(y_current)>cutoff_current_min and np.max(np.abs(np.gradient(y_current,y_current.index)))>min_gradient and np.min(np.abs(np.gradient(y_current,y_current.index)[:-10]))<max_final_gradient:
        if must_be_growth:
            if y_current.iloc[0]<y_current.iloc[-1]:
                plt.plot(x_time, y_current, '-')
                list_of_dfs_fixed.append(data)
        elif   must_be_decay:
            if y_current.iloc[0]>y_current.iloc[-1]:
                plt.plot(x_time, y_current, '-')
                list_of_dfs_fixed.append(data)          
        else:
            plt.plot(x_time, y_current, '-')
            list_of_dfs_fixed.append(data)
plt.xlabel('Time')
plt.ylabel('Current')
plt.title('Data to be modeled')
# Out:
# Text(0.5, 1.0, 'Data to be modeled')

# %%
#initialize array of expected shape
X_data = np.zeros((len(list_of_dfs_fixed),3))
#initialize array of expected shape
y_data = np.zeros((len(list_of_dfs_fixed), points, 2))

for i in range(len(list_of_dfs_fixed)):
    data = list_of_dfs_fixed[i]
    x_time = data['Time']-np.min(data['Time'])
    y_current = data['Current']
    
    if len(y_current) != target_points:
        print(points)
        continue
    if np.max(y_current)>cutoff_current_min:
        label = np.column_stack((x_time,y_current))  
        y_data[i,:,:]= label
        features =  np.array([np.min(y_current.values), data['On time'].iloc[0], data['Off time'].iloc[0]])
        X_data[i,:] = features
    prev_on_time = data['On time'].iloc[0]
    prev_off_time = data['Off time'].iloc[0]

print(f"X shape:{X_data.shape}")
print(f"y shape:{y_data.shape}")
# Out:
# X shape:(1, 3)
# y shape:(1, 50, 2)

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.0, train_size=1.0)
X_train = X_data
y_train = y_data

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)
# X_test = scaler.transform(X_test)

# %%
import keras

import tensorflow.keras.backend as K

def custom_loss(y_true, y_pred):
    """
    Custom loss function for the specified task.

    Parameters:
    - y_true: Ground truth values, of shape (batch_size, 2, N).
    - y_pred: Predicted values, of shape (batch_size, 7,N).

    Returns:
    - loss: Scalar value representing the mean loss over the batch.
    """

    # Extract x and y values from y_true
    x_values = y_true[:,:,0]  # Shape: (batch_size, N)
    y_values = y_true[:,:,1]  # Shape: (batch_size, N)
    
    function_values = tf.zeros_like(x_values)
    for i in range(int((y_pred.shape[2]-1)/2)):
        temp_val= y_pred[:, :,i]*i * K.exp(-(x_values) * y_pred[:, :,i+1]*i)
        function_values = function_values+ temp_val
    function_values = function_values+y_pred[:,:,-1]
    
    # square absolute error
    diff = (y_values -function_values) 
    squared_diff = tf.math.square(diff)
    mse = tf.math.reduce_sum(squared_diff, axis=-1)


    # diff = function_values - y_values
    # # print(diff)
    # # Take the square of the differences
    # squared_diff = K.square(diff)

    # slope_comparison = 0.0
    # for i in range(y_true.shape[2]-1):
    #     x_diff = x_values[:,i+1]-x_values[:,i]  
    #     function_slope = (function_values[:,i+1]-function_values[:,i])/x_diff 
    #     true_slope= (y_values[:,i+1]-y_values[:,i])/x_diff
    #     slope_comparison += tf.math.square(true_slope- function_slope)      

    # square relative error
    # diff = (y_values -function_values) / (y_values+0.0001) #K.maximum(y_values, y_values+0.00001)
    # squared_diff = tf.math.square(diff)
    # mse = tf.math.reduce_sum(squared_diff, axis=-1)

    loss = mse #+ slope_comparison
    # loss = K.mean(squared_diff, axis=-1)
    return loss
 

def create_nn():
    global X_train, points
    # Input layer, the number of input nodes is governed by X_data.shape[1]
    # X_data.shape[1] is the number of columns in X_data
    inputs = keras.Input(shape=(X_train.shape[1],), name='input')
    
    # Dense layers 
    #layers_norm = keras.layers.BatchNormalization()(inputs)
    layers_dense = keras.layers.Dense(10, 'linear')(inputs)
    layers_dense2 = keras.layers.Dense(10, 'linear')(layers_dense)
    # layers_dense3 = keras.layers.Dense(20, 'linear')(layers_dense2)
    # layers_dense4 = keras.layers.Dense(20, 'linear')(layers_dense3)
    # Parameter layer
    # layers_norm = keras.layers.LayerNormalization()(layers_dense2)
    parameters = keras.layers.Dense(parameter_count)(layers_dense2)
    # Expand parameters to have same shape as y_true
    expanded_parameters = keras.layers.RepeatVector(points)(parameters)


    return keras.Model(inputs=inputs, outputs=expanded_parameters, name="current_function_prediction")

# %%
if load:
    model = keras.models.load_model(model_path, custom_objects={'custom_loss':custom_loss})
else:
    model = create_nn()

model.summary()
# Out:
# Model: "current_function_prediction"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 3)]               0
#
#  dense_12 (Dense)            (None, 10)                40
#
#  dense_13 (Dense)            (None, 10)                110
#
#  dense_14 (Dense)            (None, 5)                 55
#
#  repeat_vector_4 (RepeatVec  (None, 50, 5)             0
#  tor)
#
# =================================================================
# Total params: 205 (820.00 Byte)
# Trainable params: 205 (820.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
def compile_model(model):
    sgd = keras.optimizers.RMSprop(clipnorm=5)
    model.compile(optimizer=sgd, #'adam'
                  loss=custom_loss)
    


number_of_epochs = 1000




earlystopper = keras.callbacks.EarlyStopping(monitor="loss",baseline = 1, patience=number_of_epochs,restore_best_weights=True)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='loss', 
                              factor=0.8, 
                              patience=5, 
                              min_lr=1e-6)
compile_model(model)

import seaborn as sns
def plot_history(history, metrics, y_lim):
    """
    Plot the training history

    Args:
        history (keras History object that is returned by model.fit())
        metrics (str, list): Metric or a list of metrics to plot
    """
    history_df = pd.DataFrame.from_dict(history.history)
    sns.lineplot(data=history_df[metrics])
    if y_lim !=0:
        plt.ylim(0,y_lim)
    plt.xlabel("epochs")
    plt.ylabel("metric")

# %%
history = model.fit(X_train, y_train,
                    batch_size=1,
                    epochs=number_of_epochs,
                    # validation_data = (X_val,y_val),
                    callbacks=[earlystopper
                               ,reduce_lr
                               ],
                    verbose=2)
# Out:
# Epoch 1/1000
# 1/1 - 0s - loss: 3535.0703 - lr: 0.0010 - 472ms/epoch - 472ms/step
# Epoch 2/1000
# 1/1 - 0s - loss: 1507.5890 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 517.3630 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 124.0875 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 51.4809 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 55.9213 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 23.0240 - lr: 0.0010 - 4ms/epoch - 4ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 36.8627 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 14.5392 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 29.2158 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 11.3862 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 25.5898 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 9.9778 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 23.5194 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 9.2049 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 22.1424 - lr: 0.0010 - 2ms/epoch - 2ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 8.7189 - lr: 0.0010 - 3ms/epoch - 3ms/step
# Epoch
- lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 297/1000
# 1/1 - 0s - loss: 22.4015 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 298/1000
# 1/1 - 0s - loss: 0.7016 - lr: 8.0000e-04 - 6ms/epoch - 6ms/step
# Epoch 299/1000
# 1/1 - 0s - loss: 22.5868 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 300/1000
# 1/1 - 0s - loss: 0.6834 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 301/1000
# 1/1 - 0s - loss: 22.6676 - lr: 8.0000e-04 - 4ms/epoch - 4ms/step
# Epoch 302/1000
# 1/1 - 0s - loss: 0.6637 - lr: 8.0000e-04 - 6ms/epoch - 6ms/step
# Epoch 303/1000
# 1/1 - 0s - loss: 22.8818 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 304/1000
# 1/1 - 0s - loss: 0.6523 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 305/1000
# 1/1 - 0s - loss: 22.9329 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 306/1000
# 1/1 - 0s - loss: 0.6472 - lr: 8.0000e-04 - 5ms/epoch - 5ms/step
# Epoch 307/1000
# 1/1 - 0s - loss: 23.0616 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 308/1000
# 1/1 - 0s - loss: 0.6792 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 309/1000
# 1/1 - 0s - loss: 22.9110 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 310/1000
# 1/1 - 0s - loss: 0.7088 - lr: 8.0000e-04 - 2ms/epoch - 2ms/step
# Epoch 311/1000
# 1/1 - 0s - loss: 22.6151 - lr: 8.0000e-04 - 3ms/epoch - 3ms/step
# Epoch 312/1000
# 1/1 - 0s - loss: 0.7893 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 313/1000
# 1/1 - 0s - loss: 13.3562 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 314/1000
# 1/1 - 0s - loss: 0.7243 - lr: 6.4000e-04 - 2ms/epoch - 2ms/step
# Epoch 315/1000
# 1/1 - 0s - loss: 13.3099 - lr: 6.4000e-04 - 3ms/epoch - 3ms/step
# Epoch 316/1000
# 1/1 - 0s - loss: 0.7116 - lr: 6.4000e-04 - 3ms/epoch - 3ms/step
# Epoch 317/1000
# 1/1 - 0s - loss: 13.3573 - lr: 5.1200e-04 - 3ms/epoch - 3ms/step
# Epoch 318/1000
# 1/1 - 0s - loss: 0.2756 - lr: 5.1200e-04 - 3ms/epoch - 3ms/step
# Epoch 319/1000
# 1/1 - 0s - loss: 10.6738 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 320/1000
# 1/1 - 0s - loss: 0.3299 - lr: 5.1200e-04 - 3ms/epoch - 3ms/step
# Epoch 321/1000
# 1/1 - 0s - loss: 10.0887 - lr: 5.1200e-04 - 3ms/epoch - 3ms/step
# Epoch 322/1000
# 1/1 - 0s - loss: 0.4930 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 323/1000
# 1/1 - 0s - loss: 8.8780 - lr: 5.1200e-04 - 2ms/epoch - 2ms/step
# Epoch 324/1000
# 1/1 - 0s - loss: 0.5909 - lr: 4.0960e-04 - 3ms/epoch - 3ms/step
# Epoch 325/1000
# 1/1 - 0s - loss: 5.0305 - lr: 4.0960e-04 - 3ms/epoch - 3ms/step
# Epoch 326/1000
# 1/1 - 0s - loss: 0.5205 - lr: 4.0960e-04 - 2ms/epoch - 2ms/step
# Epoch 327/1000
# 1/1 - 0s - loss: 5.0123 - lr: 4.0960e-04 - 2ms/epoch - 2ms/step
# Epoch 328/1000
# 1/1 - 0s - loss: 0.5248 - lr: 4.0960e-04 - 3ms/epoch - 3ms/step
# Epoch 329/1000
# 1/1 - 0s - loss: 4.9982 - lr: 3.2768e-04 - 2ms/epoch - 2ms/step
# Epoch 330/1000
# 1/1 - 0s - loss: 0.2114 - lr: 3.2768e-04 - 4ms/epoch - 4ms/step
# Epoch 331/1000
# 1/1 - 0s - loss: 4.1506 - lr: 3.2768e-04 - 2ms/epoch - 2ms/step
# Epoch 332/1000
# 1/1 - 0s - loss: 0.2443 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 333/1000
# 1/1 - 0s - loss: 4.0985 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 334/1000
# 1/1 - 0s - loss: 0.2516 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 335/1000
# 1/1 - 0s - loss: 3.9441 - lr: 3.2768e-04 - 3ms/epoch - 3ms/step
# Epoch 336/1000
# 1/1 - 0s - loss: 0.2724 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 337/1000
# 1/1 - 0s - loss: 2.3861 - lr: 2.6214e-04 - 3ms/epoch - 3ms/step
# Epoch 338/1000
# 1/1 - 0s - loss: 0.2687 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 339/1000
# 1/1 - 0s - loss: 2.3369 - lr: 2.6214e-04 - 2ms/epoch - 2ms/step
# Epoch 340/1000
# 1/1 - 0s - loss: 0.2745 - lr: 2.6214e-04 - 3ms/epoch - 3ms/step
# Epoch 341/1000
# 1/1 - 0s - loss: 2.3176 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 342/1000
# 1/1 - 0s - loss: 0.1827 - lr: 2.0972e-04 - 4ms/epoch - 4ms/step
# Epoch 343/1000
# 1/1 - 0s - loss: 2.0706 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 344/1000
# 1/1 - 0s - loss: 0.1829 - lr: 2.0972e-04 - 3ms/epoch - 3ms/step
# Epoch 345/1000
# 1/1 - 0s - loss: 1.6136 - lr: 2.0972e-04 - 3ms/epoch - 3ms/step
# Epoch 346/1000
# 1/1 - 0s - loss: 0.3378 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 347/1000
# 1/1 - 0s - loss: 1.3612 - lr: 2.0972e-04 - 2ms/epoch - 2ms/step
# Epoch 348/1000
# 1/1 - 0s - loss: 0.2592 - lr: 1.6777e-04 - 3ms/epoch - 3ms/step
# Epoch 349/1000
# 1/1 - 0s - loss: 0.8241 - lr: 1.6777e-04 - 2ms/epoch - 2ms/step
# Epoch 350/1000
# 1/1 - 0s - loss: 0.2575 - lr: 1.6777e-04 - 2ms/epoch - 2ms/step
# Epoch 351/1000
# 1/1 - 0s - loss: 0.8249 - lr: 1.6777e-04 - 2ms/epoch - 2ms/step
# Epoch 352/1000
# 1/1 - 0s - loss: 0.2556 - lr: 1.6777e-04 - 3ms/epoch - 3ms/step
# Epoch 353/1000
# 1/1 - 0s - loss: 0.8259 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 354/1000
# 1/1 - 0s - loss: 0.1644 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 355/1000
# 1/1 - 0s - loss: 0.8203 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 356/1000
# 1/1 - 0s - loss: 0.1594 - lr: 1.3422e-04 - 4ms/epoch - 4ms/step
# Epoch 357/1000
# 1/1 - 0s - loss: 0.8135 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 358/1000
# 1/1 - 0s - loss: 0.1545 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 359/1000
# 1/1 - 0s - loss: 0.8060 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 360/1000
# 1/1 - 0s - loss: 0.1495 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 361/1000
# 1/1 - 0s - loss: 0.7971 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 362/1000
# 1/1 - 0s - loss: 0.1447 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 363/1000
# 1/1 - 0s - loss: 0.7879 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 364/1000
# 1/1 - 0s - loss: 0.1399 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 365/1000
# 1/1 - 0s - loss: 0.7767 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 366/1000
# 1/1 - 0s - loss: 0.1352 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 367/1000
# 1/1 - 0s - loss: 0.7660 - lr: 1.3422e-04 - 4ms/epoch - 4ms/step
# Epoch 368/1000
# 1/1 - 0s - loss: 0.1306 - lr: 1.3422e-04 - 5ms/epoch - 5ms/step
# Epoch 369/1000
# 1/1 - 0s - loss: 0.7524 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 370/1000
# 1/1 - 0s - loss: 0.1264 - lr: 1.3422e-04 - 4ms/epoch - 4ms/step
# Epoch 371/1000
# 1/1 - 0s - loss: 0.7406 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 372/1000
# 1/1 - 0s - loss: 0.1221 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 373/1000
# 1/1 - 0s - loss: 0.7247 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 374/1000
# 1/1 - 0s - loss: 0.1186 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 375/1000
# 1/1 - 0s - loss: 0.7123 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 376/1000
# 1/1 - 0s - loss: 0.1150 - lr: 1.3422e-04 - 4ms/epoch - 4ms/step
# Epoch 377/1000
# 1/1 - 0s - loss: 0.6946 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 378/1000
# 1/1 - 0s - loss: 0.1125 - lr: 1.3422e-04 - 4ms/epoch - 4ms/step
# Epoch 379/1000
# 1/1 - 0s - loss: 0.6820 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 380/1000
# 1/1 - 0s - loss: 0.1099 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 381/1000
# 1/1 - 0s - loss: 0.6641 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 382/1000
# 1/1 - 0s - loss: 0.1087 - lr: 1.3422e-04 - 4ms/epoch - 4ms/step
# Epoch 383/1000
# 1/1 - 0s - loss: 0.6513 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 384/1000
# 1/1 - 0s - loss: 0.1074 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 385/1000
# 1/1 - 0s - loss: 0.6352 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 386/1000
# 1/1 - 0s - loss: 0.1073 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 387/1000
# 1/1 - 0s - loss: 0.6235 - lr: 1.3422e-04 - 2ms/epoch - 2ms/step
# Epoch 388/1000
# 1/1 - 0s - loss: 0.1073 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 389/1000
# 1/1 - 0s - loss: 0.6105 - lr: 1.3422e-04 - 3ms/epoch - 3ms/step
# Epoch 390/1000
# 1/1 - 0s - loss: 0.1081 - lr: 1.0737e-04 - 2ms/epoch - 2ms/step
# Epoch 391/1000
# 1/1 - 0s - loss: 0.3535 - lr: 1.0737e-04 - 3ms/epoch - 3ms/step
# Epoch 392/1000
# 1/1 - 0s - loss: 0.1088 - lr: 1.0737e-04 - 2ms/epoch - 2ms/step
# Epoch 393/1000
# 1/1 - 0s - loss: 0.3446 - lr: 1.0737e-04 - 3ms/epoch - 3ms/step
# Epoch 394/1000
# 1/1 - 0s - loss: 0.1098 - lr: 1.0737e-04 - 2ms/epoch - 2ms/step
# Epoch 395/1000
# 1/1 - 0s - loss: 0.3364 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 396/1000
# 1/1 - 0s - loss: 0.0575 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 397/1000
# 1/1 - 0s - loss: 0.3153 - lr: 8.5899e-05 - 2ms/epoch - 2ms/step
# Epoch 398/1000
# 1/1 - 0s - loss: 0.0558 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 399/1000
# 1/1 - 0s - loss: 0.3037 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 400/1000
# 1/1 - 0s - loss: 0.0546 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 401/1000
# 1/1 - 0s - loss: 0.2872 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 402/1000
# 1/1 - 0s - loss: 0.0553 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 403/1000
# 1/1 - 0s - loss: 0.2770 - lr: 8.5899e-05 - 2ms/epoch - 2ms/step
# Epoch 404/1000
# 1/1 - 0s - loss: 0.0557 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 405/1000
# 1/1 - 0s - loss: 0.2658 - lr: 8.5899e-05 - 3ms/epoch - 3ms/step
# Epoch 406/1000
# 1/1 - 0s - loss: 0.0570 - lr: 6.8719e-05 - 3ms/epoch - 3ms/step
# Epoch 407/1000
# 1/1 - 0s - loss: 0.1508 - lr: 6.8719e-05 - 5ms/epoch - 5ms/step
# Epoch 408/1000
# 1/1 - 0s - loss: 0.0580 - lr: 6.8719e-05 - 4ms/epoch - 4ms/step
# Epoch 409/1000
# 1/1 - 0s - loss: 0.1444 - lr: 6.8719e-05 - 2ms/epoch - 2ms/step
# Epoch 410/1000
# 1/1 - 0s - loss: 0.0591 - lr: 6.8719e-05 - 4ms/epoch - 4ms/step
# Epoch 411/1000
# 1/1 - 0s - loss: 0.1389 - lr: 5.4976e-05 - 4ms/epoch - 4ms/step
# Epoch 412/1000
# 1/1 - 0s - loss: 0.0317 - lr: 5.4976e-05 - 4ms/epoch - 4ms/step
# Epoch 413/1000
# 1/1 - 0s - loss: 0.1291 - lr: 5.4976e-05 - 2ms/epoch - 2ms/step
# Epoch 414/1000
# 1/1 - 0s - loss: 0.0317 - lr: 5.4976e-05 - 5ms/epoch - 5ms/step
# Epoch 415/1000
# 1/1 - 0s - loss: 0.1218 - lr: 5.4976e-05 - 4ms/epoch - 4ms/step
# Epoch 416/1000
# 1/1 - 0s - loss: 0.0320 - lr: 5.4976e-05 - 2ms/epoch - 2ms/step
# Epoch 417/1000
# 1/1 - 0s - loss: 0.1154 - lr: 5.4976e-05 - 3ms/epoch - 3ms/step
# Epoch 418/1000
# 1/1 - 0s - loss: 0.0327 - lr: 4.3980e-05 - 2ms/epoch - 2ms/step
# Epoch 419/1000
# 1/1 - 0s - loss: 0.0660 - lr: 4.3980e-05 - 2ms/epoch - 2ms/step
# Epoch 420/1000
# 1/1 - 0s - loss: 0.0332 - lr: 4.3980e-05 - 2ms/epoch - 2ms/step
# Epoch 421/1000
# 1/1 - 0s - loss: 0.0627 - lr: 4.3980e-05 - 3ms/epoch - 3ms/step
# Epoch 422/1000
# 1/1 - 0s - loss: 0.0338 - lr: 4.3980e-05 - 2ms/epoch - 2ms/step
# Epoch 423/1000
# 1/1 - 0s - loss: 0.0597 - lr: 3.5184e-05 - 3ms/epoch - 3ms/step
# Epoch 424/1000
# 1/1 - 0s - loss: 0.0203 - lr: 3.5184e-05 - 4ms/epoch - 4ms/step
# Epoch 425/1000
# 1/1 - 0s - loss: 0.0555 - lr: 3.5184e-05 - 2ms/epoch - 2ms/step
# Epoch 426/1000
# 1/1 - 0s - loss: 0.0203 - lr: 3.5184e-05 - 2ms/epoch - 2ms/step
# Epoch 427/1000
# 1/1 - 0s - loss: 0.0521 - lr: 3.5184e-05 - 3ms/epoch - 3ms/step
# Epoch 428/1000
# 1/1 - 0s - loss: 0.0205 - lr: 3.5184e-05 - 2ms/epoch - 2ms/step
# Epoch 429/1000
# 1/1 - 0s - loss: 0.0492 - lr: 3.5184e-05 - 3ms/epoch - 3ms/step
# Epoch 430/1000
# 1/1 - 0s - loss: 0.0208 - lr: 2.8147e-05 - 2ms/epoch - 2ms/step
# Epoch 431/1000
# 1/1 - 0s - loss: 0.0294 - lr: 2.8147e-05 - 3ms/epoch - 3ms/step
# Epoch 432/1000
# 1/1 - 0s - loss: 0.0210 - lr: 2.8147e-05 - 2ms/epoch - 2ms/step
# Epoch 433/1000
# 1/1 - 0s - loss: 0.0278 - lr: 2.8147e-05 - 3ms/epoch - 3ms/step
# Epoch 434/1000
# 1/1 - 0s - loss: 0.0212 - lr: 2.8147e-05 - 3ms/epoch - 3ms/step
# Epoch 435/1000
# 1/1 - 0s - loss: 0.0264 - lr: 2.2518e-05 - 2ms/epoch - 2ms/step
# Epoch 436/1000
# 1/1 - 0s - loss: 0.0143 - lr: 2.2518e-05 - 3ms/epoch - 3ms/step
# Epoch 437/1000
# 1/1 - 0s - loss: 0.0247 - lr: 2.2518e-05 - 3ms/epoch - 3ms/step
# Epoch 438/1000
# 1/1 - 0s - loss: 0.0143 - lr: 2.2518e-05 - 2ms/epoch - 2ms/step
# Epoch 439/1000
# 1/1 - 0s - loss: 0.0232 - lr: 2.2518e-05 - 2ms/epoch - 2ms/step
# Epoch 440/1000
# 1/1 - 0s - loss: 0.0143 - lr: 2.2518e-05 - 2ms/epoch - 2ms/step
# Epoch 441/1000
# 1/1 - 0s - loss: 0.0219 - lr: 2.2518e-05 - 3ms/epoch - 3ms/step
# Epoch 442/1000
# 1/1 - 0s - loss: 0.0144 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 443/1000
# 1/1 - 0s - loss: 0.0144 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 444/1000
# 1/1 - 0s - loss: 0.0145 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 445/1000
# 1/1 - 0s - loss: 0.0137 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 446/1000
# 1/1 - 0s - loss: 0.0145 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 447/1000
# 1/1 - 0s - loss: 0.0130 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 448/1000
# 1/1 - 0s - loss: 0.0146 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 449/1000
# 1/1 - 0s - loss: 0.0124 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 450/1000
# 1/1 - 0s - loss: 0.0146 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 451/1000
# 1/1 - 0s - loss: 0.0119 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 452/1000
# 1/1 - 0s - loss: 0.0147 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 453/1000
# 1/1 - 0s - loss: 0.0114 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 454/1000
# 1/1 - 0s - loss: 0.0147 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 455/1000
# 1/1 - 0s - loss: 0.0109 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 456/1000
# 1/1 - 0s - loss: 0.0148 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 457/1000
# 1/1 - 0s - loss: 0.0105 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 458/1000
# 1/1 - 0s - loss: 0.0148 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 459/1000
# 1/1 - 0s - loss: 0.0102 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 460/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 461/1000
# 1/1 - 0s - loss: 0.0098 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 462/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 463/1000
# 1/1 - 0s - loss: 0.0095 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 464/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 465/1000
# 1/1 - 0s - loss: 0.0092 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 466/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 467/1000
# 1/1 - 0s - loss: 0.0089 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 468/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 469/1000
# 1/1 - 0s - loss: 0.0086 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 470/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 471/1000
# 1/1 - 0s - loss: 0.0084 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 472/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 473/1000
# 1/1 - 0s - loss: 0.0082 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 474/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 475/1000
# 1/1 - 0s - loss: 0.0080 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 476/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 477/1000
# 1/1 - 0s - loss: 0.0078 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 478/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 479/1000
# 1/1 - 0s - loss: 0.0076 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 480/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 481/1000
# 1/1 - 0s - loss: 0.0074 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 482/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 483/1000
# 1/1 - 0s - loss: 0.0073 - lr: 1.8014e-05 - 6ms/epoch - 6ms/step
# Epoch 484/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 5ms/epoch - 5ms/step
# Epoch 485/1000
# 1/1 - 0s - loss: 0.0071 - lr: 1.8014e-05 - 5ms/epoch - 5ms/step
# Epoch 486/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 487/1000
# 1/1 - 0s - loss: 0.0070 - lr: 1.8014e-05 - 5ms/epoch - 5ms/step
# Epoch 488/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 489/1000
# 1/1 - 0s - loss: 0.0068 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 490/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 491/1000
# 1/1 - 0s - loss: 0.0067 - lr: 1.8014e-05 - 6ms/epoch - 6ms/step
# Epoch 492/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 493/1000
# 1/1 - 0s - loss: 0.0066 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 494/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 495/1000
# 1/1 - 0s - loss: 0.0065 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 496/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 497/1000
# 1/1 - 0s - loss: 0.0064 - lr: 1.8014e-05 - 6ms/epoch - 6ms/step
# Epoch 498/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 499/1000
# 1/1 - 0s - loss: 0.0063 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 500/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 501/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 502/1000
# 1/1 - 0s - loss: 0.0150 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 503/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.8014e-05 - 4ms/epoch - 4ms/step
# Epoch 504/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 505/1000
# 1/1 - 0s - loss: 0.0061 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 506/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 507/1000
# 1/1 - 0s - loss: 0.0060 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 508/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 509/1000
# 1/1 - 0s - loss: 0.0060 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 510/1000
# 1/1 - 0s - loss: 0.0149 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 511/1000
# 1/1 - 0s - loss: 0.0059 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 512/1000
# 1/1 - 0s - loss: 0.0148 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 513/1000
# 1/1 - 0s - loss: 0.0059 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 514/1000
# 1/1 - 0s - loss: 0.0148 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 515/1000
# 1/1 - 0s - loss: 0.0058 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 516/1000
# 1/1 - 0s - loss: 0.0148 - lr: 1.8014e-05 - 2ms/epoch - 2ms/step
# Epoch 517/1000
# 1/1 - 0s - loss: 0.0058 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 518/1000
# 1/1 - 0s - loss: 0.0148 - lr: 1.8014e-05 - 3ms/epoch - 3ms/step
# Epoch 519/1000
# 1/1 - 0s - loss: 0.0057 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 520/1000
# 1/1 - 0s - loss: 0.0092 - lr: 1.4412e-05 - 2ms/epoch - 2ms/step
# Epoch 521/1000
# 1/1 - 0s - loss: 0.0057 - lr: 1.4412e-05 - 4ms/epoch - 4ms/step
# Epoch 522/1000
# 1/1 - 0s - loss: 0.0092 - lr: 1.4412e-05 - 2ms/epoch - 2ms/step
# Epoch 523/1000
# 1/1 - 0s - loss: 0.0056 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 524/1000
# 1/1 - 0s - loss: 0.0092 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 525/1000
# 1/1 - 0s - loss: 0.0055 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 526/1000
# 1/1 - 0s - loss: 0.0092 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 527/1000
# 1/1 - 0s - loss: 0.0055 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 528/1000
# 1/1 - 0s - loss: 0.0093 - lr: 1.4412e-05 - 2ms/epoch - 2ms/step
# Epoch 529/1000
# 1/1 - 0s - loss: 0.0054 - lr: 1.4412e-05 - 4ms/epoch - 4ms/step
# Epoch 530/1000
# 1/1 - 0s - loss: 0.0093 - lr: 1.4412e-05 - 2ms/epoch - 2ms/step
# Epoch 531/1000
# 1/1 - 0s - loss: 0.0054 - lr: 1.4412e-05 - 3ms/epoch - 3ms/step
# Epoch 532/1000
# 1/1 - 0s - loss: 0.0093 - lr: 1.4412e-05 - 2ms/epoch - 2ms/step
# Epoch 533/1000
# 1/1 - 0s - loss: 0.0054 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 534/1000
# 1/1 - 0s - loss: 0.0061 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 535/1000
# 1/1 - 0s - loss: 0.0053 - lr: 1.1529e-05 - 4ms/epoch - 4ms/step
# Epoch 536/1000
# 1/1 - 0s - loss: 0.0061 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 537/1000
# 1/1 - 0s - loss: 0.0052 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 538/1000
# 1/1 - 0s - loss: 0.0061 - lr: 1.1529e-05 - 2ms/epoch - 2ms/step
# Epoch 539/1000
# 1/1 - 0s - loss: 0.0052 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 540/1000
# 1/1 - 0s - loss: 0.0061 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 541/1000
# 1/1 - 0s - loss: 0.0051 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 542/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.1529e-05 - 2ms/epoch - 2ms/step
# Epoch 543/1000
# 1/1 - 0s - loss: 0.0051 - lr: 1.1529e-05 - 4ms/epoch - 4ms/step
# Epoch 544/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 545/1000
# 1/1 - 0s - loss: 0.0050 - lr: 1.1529e-05 - 4ms/epoch - 4ms/step
# Epoch 546/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.1529e-05 - 2ms/epoch - 2ms/step
# Epoch 547/1000
# 1/1 - 0s - loss: 0.0050 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 548/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.1529e-05 - 2ms/epoch - 2ms/step
# Epoch 549/1000
# 1/1 - 0s - loss: 0.0049 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 550/1000
# 1/1 - 0s - loss: 0.0062 - lr: 1.1529e-05 - 3ms/epoch - 3ms/step
# Epoch 551/1000
# 1/1 - 0s - loss: 0.0049 - lr: 9.2234e-06 - 6ms/epoch - 6ms/step
# Epoch 552/1000
# 1/1 - 0s - loss: 0.0044 - lr: 9.2234e-06 - 6ms/epoch - 6ms/step
# Epoch 553/1000
# 1/1 - 0s - loss: 0.0048 - lr: 9.2234e-06 - 4ms/epoch - 4ms/step
# Epoch 554/1000
# 1/1 - 0s - loss: 0.0044 - lr: 9.2234e-06 - 5ms/epoch - 5ms/step
# Epoch 555/1000
# 1/1 - 0s - loss: 0.0048 - lr: 9.2234e-06 - 5ms/epoch - 5ms/step
# Epoch 556/1000
# 1/1 - 0s - loss: 0.0045 - lr: 9.2234e-06 - 2ms/epoch - 2ms/step
# Epoch 557/1000
# 1/1 - 0s - loss: 0.0047 - lr: 9.2234e-06 - 3ms/epoch - 3ms/step
# Epoch 558/1000
# 1/1 - 0s - loss: 0.0045 - lr: 7.3787e-06 - 4ms/epoch - 4ms/step
# Epoch 559/1000
# 1/1 - 0s - loss: 0.0036 - lr: 7.3787e-06 - 4ms/epoch - 4ms/step
# Epoch 560/1000
# 1/1 - 0s - loss: 0.0045 - lr: 7.3787e-06 - 3ms/epoch - 3ms/step
# Epoch 561/1000
# 1/1 - 0s - loss: 0.0036 - lr: 7.3787e-06 - 3ms/epoch - 3ms/step
# Epoch 562/1000
# 1/1 - 0s - loss: 0.0045 - lr: 7.3787e-06 - 2ms/epoch - 2ms/step
# Epoch 563/1000
# 1/1 - 0s - loss: 0.0036 - lr: 7.3787e-06 - 4ms/epoch - 4ms/step
# Epoch 564/1000
# 1/1 - 0s - loss: 0.0045 - lr: 7.3787e-06 - 2ms/epoch - 2ms/step
# Epoch 565/1000
# 1/1 - 0s - loss: 0.0035 - lr: 5.9030e-06 - 4ms/epoch - 4ms/step
# Epoch 566/1000
# 1/1 - 0s - loss: 0.0037 - lr: 5.9030e-06 - 2ms/epoch - 2ms/step
# Epoch 567/1000
# 1/1 - 0s - loss: 0.0035 - lr: 5.9030e-06 - 3ms/epoch - 3ms/step
# Epoch 568/1000
# 1/1 - 0s - loss: 0.0037 - lr: 5.9030e-06 - 3ms/epoch - 3ms/step
# Epoch 569/1000
# 1/1 - 0s - loss: 0.0035 - lr: 5.9030e-06 - 3ms/epoch - 3ms/step
# Epoch 570/1000
# 1/1 - 0s - loss: 0.0037 - lr: 5.9030e-06 - 2ms/epoch - 2ms/step
# Epoch 571/1000
# 1/1 - 0s - loss: 0.0035 - lr: 5.9030e-06 - 3ms/epoch - 3ms/step
# Epoch 572/1000
# 1/1 - 0s - loss: 0.0037 - lr: 5.9030e-06 - 2ms/epoch - 2ms/step
# Epoch 573/1000
# 1/1 - 0s - loss: 0.0034 - lr: 4.7224e-06 - 3ms/epoch - 3ms/step
# Epoch 574/1000
# 1/1 - 0s - loss: 0.0032 - lr: 4.7224e-06 - 3ms/epoch - 3ms/step
# Epoch 575/1000
# 1/1 - 0s - loss: 0.0034 - lr: 4.7224e-06 - 2ms/epoch - 2ms/step
# Epoch 576/1000
# 1/1 - 0s - loss: 0.0032 - lr: 4.7224e-06 - 4ms/epoch - 4ms/step
# Epoch 577/1000
# 1/1 - 0s - loss: 0.0034 - lr: 4.7224e-06 - 2ms/epoch - 2ms/step
# Epoch 578/1000
# 1/1 - 0s - loss: 0.0032 - lr: 4.7224e-06 - 5ms/epoch - 5ms/step
# Epoch 579/1000
# 1/1 - 0s - loss: 0.0033 - lr: 4.7224e-06 - 2ms/epoch - 2ms/step
# Epoch 580/1000
# 1/1 - 0s - loss: 0.0032 - lr: 3.7779e-06 - 3ms/epoch - 3ms/step
# Epoch 581/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.7779e-06 - 3ms/epoch - 3ms/step
# Epoch 582/1000
# 1/1 - 0s - loss: 0.0032 - lr: 3.7779e-06 - 3ms/epoch - 3ms/step
# Epoch 583/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.7779e-06 - 4ms/epoch - 4ms/step
# Epoch 584/1000
# 1/1 - 0s - loss: 0.0032 - lr: 3.7779e-06 - 3ms/epoch - 3ms/step
# Epoch 585/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.7779e-06 - 3ms/epoch - 3ms/step
# Epoch 586/1000
# 1/1 - 0s - loss: 0.0032 - lr: 3.7779e-06 - 2ms/epoch - 2ms/step
# Epoch 587/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.0223e-06 - 3ms/epoch - 3ms/step
# Epoch 588/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.0223e-06 - 3ms/epoch - 3ms/step
# Epoch 589/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.0223e-06 - 3ms/epoch - 3ms/step
# Epoch 590/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.0223e-06 - 3ms/epoch - 3ms/step
# Epoch 591/1000
# 1/1 - 0s - loss: 0.0030 - lr: 3.0223e-06 - 4ms/epoch - 4ms/step
# Epoch 592/1000
# 1/1 - 0s - loss: 0.0030 - lr: 2.4179e-06 - 2ms/epoch - 2ms/step
# Epoch 593/1000
# 1/1 - 0s - loss: 0.0029 - lr: 2.4179e-06 - 3ms/epoch - 3ms/step
# Epoch 594/1000
# 1/1 - 0s - loss: 0.0030 - lr: 2.4179e-06 - 3ms/epoch - 3ms/step
# Epoch 595/1000
# 1/1 - 0s - loss: 0.0028 - lr: 2.4179e-06 - 3ms/epoch - 3ms/step
# Epoch 596/1000
# 1/1 - 0s - loss: 0.0030 - lr: 2.4179e-06 - 3ms/epoch - 3ms/step
# Epoch 597/1000
# 1/1 - 0s - loss: 0.0028 - lr: 2.4179e-06 - 3ms/epoch - 3ms/step
# Epoch 598/1000
# 1/1 - 0s - loss: 0.0030 - lr: 2.4179e-06 - 2ms/epoch - 2ms/step
# Epoch 599/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.9343e-06 - 3ms/epoch - 3ms/step
# Epoch 600/1000
# 1/1 - 0s - loss: 0.0029 - lr: 1.9343e-06 - 2ms/epoch - 2ms/step
# Epoch 601/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.9343e-06 - 4ms/epoch - 4ms/step
# Epoch 602/1000
# 1/1 - 0s - loss: 0.0029 - lr: 1.9343e-06 - 2ms/epoch - 2ms/step
# Epoch 603/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.9343e-06 - 4ms/epoch - 4ms/step
# Epoch 604/1000
# 1/1 - 0s - loss: 0.0029 - lr: 1.5474e-06 - 3ms/epoch - 3ms/step
# Epoch 605/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.5474e-06 - 3ms/epoch - 3ms/step
# Epoch 606/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.5474e-06 - 2ms/epoch - 2ms/step
# Epoch 607/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.5474e-06 - 2ms/epoch - 2ms/step
# Epoch 608/1000
# 1/1 - 0s - loss: 0.0028 - lr: 1.5474e-06 - 3ms/epoch - 3ms/step
# Epoch 609/1000
# ...
# Epoch 799/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 800/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 801/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 802/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 803/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 804/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 805/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 806/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 807/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 808/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 809/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 810/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 811/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 812/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 813/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 814/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 815/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 816/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 817/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 818/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 819/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 820/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 821/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 822/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 823/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 824/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 825/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 826/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 827/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 828/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 6ms/epoch - 6ms/step
# Epoch 829/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 830/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 831/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 832/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 15ms/epoch - 15ms/step
# Epoch 833/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 834/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 835/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 6ms/epoch - 6ms/step
# Epoch 836/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 837/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 838/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 839/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 840/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 841/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 842/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 843/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 844/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 845/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 846/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 847/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 848/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 849/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 850/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 851/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 852/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 853/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 854/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 855/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 856/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 857/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 858/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 859/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 860/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 861/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 862/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 863/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 864/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 865/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 866/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 867/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 868/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 869/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 870/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 871/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 872/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 873/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 874/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 875/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 5ms/epoch - 5ms/step
# Epoch 876/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 877/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 878/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 879/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 880/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 881/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 882/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 883/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 884/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 885/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 886/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 887/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 888/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 889/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 890/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 891/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 892/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 893/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 894/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 895/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 896/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 897/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 898/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 899/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 900/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 901/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 902/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 5ms/epoch - 5ms/step
# Epoch 903/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 904/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 905/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 906/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 907/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 908/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 909/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 910/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 911/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 912/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 913/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 914/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 5ms/epoch - 5ms/step
# Epoch 915/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 916/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 917/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 918/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 919/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 920/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 921/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 922/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 923/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 924/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 925/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 926/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 927/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 928/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 929/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 930/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 931/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 932/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 933/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 934/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 935/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 936/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 937/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 938/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 939/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 940/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 941/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 942/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 943/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 944/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 945/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 946/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 947/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 948/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 949/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 950/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 951/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 952/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 953/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 954/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 7ms/epoch - 7ms/step
# Epoch 955/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 956/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 957/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 5ms/epoch - 5ms/step
# Epoch 958/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 6ms/epoch - 6ms/step
# Epoch 959/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 960/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 961/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 962/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 963/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 964/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 965/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 966/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 967/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 968/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 4ms/epoch - 4ms/step
# Epoch 969/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 970/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 971/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 972/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 973/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 974/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 975/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 976/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 977/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 978/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 979/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 980/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 981/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 982/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 983/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 984/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 985/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 986/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 987/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 988/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 989/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 990/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 991/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 992/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 993/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 994/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 995/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 996/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 997/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 998/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 2ms/epoch - 2ms/step
# Epoch 999/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step
# Epoch 1000/1000
# 1/1 - 0s - loss: 0.0027 - lr: 1.0000e-06 - 3ms/epoch - 3ms/step

# %%
# call the plot_history function with the apropriate object and string
plot_history(history, ['loss'], 0)

# %%
# # Save the model
# import os
# from datetime import datetime
# current_date = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
# # filename = f"{current_date}_RMSE_params_{model.count_params()}_points_{points}.keras"
# # model.save('models/'+filename)


# folder_path = f'models/{current_date}_{exponential_count}exp_params_{model.count_params()}_points_{points}'
# os.makedirs(folder_path, exist_ok=True)
# model.save(folder_path+'/model.keras')

# %%
# make prediction on test data
y_train_prediction = model.predict(X_train)
# Out:
# 1/1 [==============================] - 0s 43ms/step

# %%
plt.figure(figsize=(12, 6))

y_train_prediction = model.predict(X_train)

# from matplotlib.pyplot import cm
# color = iter(cm.rainbow(np.linspace(0, 1, X_test.shape[0]-5)))
plt.subplot(1, 2, 1)
for test_entry_index in range(X_train.shape[0]):
    y_true = y_train[test_entry_index,:,:]
    param_predicted = y_train_prediction[test_entry_index,0 ,: ]
    plt.plot(y_true[:,0], -(y_true[:,1]- model_function.exponential_function_param_specific(y_true[:,0], param_predicted))/y_true[:,1], '-', color = 'C0', alpha = 0.3, )


plt.xlabel('time')
plt.ylabel('Relative error')
plt.title('Relative Error of test data prediction')
# Out:
# 1/1 [==============================] - 0s 15ms/step
# Text(0.5, 1.0, 'Relative Error of test data prediction')

# %% [markdown]
# Relative error plots

# %%
plt.figure(figsize=(12, 6))

y_train_prediction = model.predict(X_train)

plt.subplot(1, 2, 1)
for test_entry_index in range(X_train.shape[0]):
    y_true = y_train[test_entry_index,:,:]
    param_predicted = y_train_prediction[test_entry_index,0 ,: ]
    plt.plot(y_true[:,0], y_true[:,1], '-', color = 'C0', alpha = 0.3, )
    plt.plot(y_true[:,0], model_function.exponential_function_param_specific(y_true[:,0], param_predicted), '-', color = 'C0', alpha = 1, )

    
plt.xlabel('time')
plt.ylabel('Current (mA)')
plt.title('True vs prediction')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Text(0.5, 1.0, 'True vs prediction')
